# %% [markdown]
# ### **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Load Data**

# %%
# Load Dataset
df = pd.read_csv('../data/amazon_delivery.csv')

# Cek 5 data teratas
print("=== 5 DATA PERTAMA ===")
display(df.head())

# Cek Info Data
print("\n=== INFO DATASET ===")
df.info()

# %% [markdown]
# ### _**Data Cleaning**_

# %%
# Cek jumlah data kosong per kolom
print("Jumlah data kosong sebelum cleaning:")
print(df.isnull().sum())

# Hapus baris yang ada data kosongnya (biar aman hitungannya)
df_clean = df.dropna()

print(f"\nJumlah data setelah dibersihkan: {len(df_clean)} baris")
print("Sisa data kosong:")
print(df_clean.isnull().sum())
